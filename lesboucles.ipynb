# %% [markdown]
# # La boucle for

# %% [markdown]
# Imaginez que vous ayez une liste de quatre éléments dont vous voulez afficher les éléments les uns après les autres. Pour faire cela, on peut utiliser les boucles.

# %%
animaux = ['girafe','tigre','singe','souris']
for animal in animaux:
       print(animal)
# Out:
# girafe
# tigre
# singe
# souris

# %% [markdown]
# Outre une meilleure lisibilité́, ceci est formellement requis en Python.
#
# Toutes les instructions que l’on veut répéter constituent le corps de la boucle (ou un bloc d’instructions) et doivent être indentées d’un(e) ou plusieurs espace(s) ou tabulation(s).
#
# Dans le cas contraire, Python vous renvoie un message d’erreur.

# %% [markdown]
# Il est aussi possible d’utiliser une tranche d’une liste :

# %%
animaux = ['girafe','tigre','singe','souris']
for animal in animaux[1:3]:
    print(animal)
# Out:
# tigre
# singe

# %% [markdown]
# On a vu que les boucles for pouvaient utiliser une liste contenant des chaines de caractères, mais elles peuvent tout aussi bien utiliser des listes numériques.
#
# En utilisant l’instruction range on peut facilement accéder à une liste d’entiers.

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# # La boucle while

# %% [markdown]
# Une autre alternative à l’instruction for couramment utilisée en informatique est la boucle while.
#
# Le principe est simple. Une série d’instructions est exécutée tant qu’une condition est vraie.

# %%
 i = 1
while i <= 4:
        print(i) 
        i=i+1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Exercices:
#
# 1) Écrire un programme nommé table_de_9.py qui affiche la table de 9.
#
# 2) Écrire un programme nommé somme.py permettant de calculer la somme des entiers naturels pairs inférieurs ou égaux à un entier donné.
#
# 3) Écrire un programme nommé liste.py qui permet d’afficher la liste
# ['ad', 'ae', 'bd', 'be', 'cd', 'ce'] à partir des chaines "abc" et "de".
